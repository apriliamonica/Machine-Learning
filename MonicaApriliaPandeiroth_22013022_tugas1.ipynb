# %% [markdown]
# <a href="https://colab.research.google.com/github/apriliamonica/Machine-Learning/blob/main/MonicaApriliaPandeiroth_22013022_tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

data = {'x' :  [23, 26, 30, 34, 43, 48, 52, 57, 58, 60], 'y' : [651, 762, 856, 1063, 1190, 1298, 1421, 1440, 1518, 1576]}
df = pd.DataFrame(data)

plt.scatter(df['x'], df['y'])
plt.xlabel("Masa Kerja (x)")
plt.ylabel("Pendapatan (Y)")
plt.title("Scatter Plot Masa Kerja vs Pendapatan")
plt.show()

# %%
x = df['x'].values.reshape(-1,1)
y = df['y'].values.reshape(-1,1)

model = LinearRegression()
model.fit(x, y)
a = model.coef_
b = model.intercept_

plt.scatter(x, y, color='blue', label="Data Asli")
plt.plot(x, model.predict(x), color='red', label="Garis Regresi")
plt.xlabel("Masa Kerja (x)")
plt.ylabel("Pendapatan (Y)")
plt.title("Regresi Linear Sederhana: Masa Kerja vs Pendapatan")
plt.legend()
plt.show()
